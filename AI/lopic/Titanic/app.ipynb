# %%
import pandas as pd
df = pd.read_csv("train.csv", encoding = "utf-8")

# %%
df = df.drop(["PassengerId","Ticket","Cabin"], axis = 1)
df = pd.get_dummies(df[["Sex", "Embarked"]], drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/kn/5zys6lyj3xl_1lqz1ftr_wqc0000gn/T/ipykernel_30605/3496693107.py in ?()
# ----> 2 df = df.drop(["PassengerId","Ticket","Cabin"], axis = 1)
#       3 df = df.concat(pd.get_dummies(df[["Sex", "Embarked"]], drop_first=True),axis = 1)
#       4 df
#
# /opt/miniconda3/envs/Cvenv/lib/python3.9/site-packages/pandas/core/generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'concat'
